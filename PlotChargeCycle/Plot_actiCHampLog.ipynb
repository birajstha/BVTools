# %%
import matplotlib
#matplotlib.use('Qt5Agg')
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]
import os

cwd = os.getcwd()

x_values = []
y_values = []

p = os.path.join(cwd, 'actiCHamp.log')

f = open(p, 'r')
for row in f:
    row = row.split(';')
    
    if (float(row[5]) > 8):
        print("Invalid Voltage! >> " + row[5] +"V  >> " + row[0] + " Check Amplifier >> "+row[6])
    x_values.append(row[0])
    y_values.append(float(row[5]))

plt.plot(x_values, y_values, color = 'g')

plt.xlabel('Date/Time', fontsize = 12)
plt.ylabel('Voltage', fontsize = 12)

plt.xticks(x_values[::30],  rotation='vertical')
plt.margins(0.02)

plt.ylim(bottom= 5, top= 7.5)
plt.axhline(y= 5.5, color='red', linestyle = 'dotted', linewidth = 1, label = 'Cutoff is 5.5V')

plt.title('Charge Cycle', fontsize = 20)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Invalid Voltage! >>  18.625V  >> 2021-10-22 11:31:33.582 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.625V  >> 2021-10-22 11:32:47.826 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.522V  >> 2021-10-22 11:33:47.836 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.625V  >> 2021-10-22 11:38:21.805 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 11:39:21.851 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.522V  >> 2021-10-22 11:40:22.596 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.508V  >> 2021-10-22 11:41:22.688 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.552V  >> 2021-10-22 11:43:02.502 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.522V  >> 2021-10-22 11:44:02.812 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.522V  >> 2021-10-22 11:45:03.557 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.464V  >> 2021-10-22 11:46:03.613 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.566V  >> 2021-10-22 11:49:02.705 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.508V  >> 2021-10-22 11:50:03.492 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.420V  >> 2021-10-22 11:51:03.548 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.581V  >> 2021-10-22 11:52:52.967 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.449V  >> 2021-10-22 11:53:53.010 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 11:54:53.779 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.449V  >> 2021-10-22 11:55:53.782 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.420V  >> 2021-10-22 12:31:12.773 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.449V  >> 2021-10-22 12:32:14.963 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.347V  >> 2021-10-22 12:33:17.016 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.420V  >> 2021-10-22 12:34:19.226 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.464V  >> 2021-10-22 13:45:35.407 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.449V  >> 2021-10-22 13:46:39.117 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.405V  >> 2021-10-22 13:47:42.816 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.405V  >> 2021-10-22 13:48:46.792 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.405V  >> 2021-10-22 13:49:50.745 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 13:50:54.632 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 13:51:58.460 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 13:53:02.136 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 13:54:09.555 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.376V  >> 2021-10-22 16:07:50.238 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.405V  >> 2021-10-22 16:08:53.932 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.449V  >> 2021-10-22 16:13:24.246 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.405V  >> 2021-10-22 16:14:27.789 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:15:31.473 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:16:35.013 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:17:38.835 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:18:42.525 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:19:46.352 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:20:50.034 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:21:53.724 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:22:57.402 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.420V  >> 2021-10-22 16:24:00.937 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.376V  >> 2021-10-22 16:25:04.625 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.376V  >> 2021-10-22 16:26:08.335 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.435V  >> 2021-10-22 16:27:12.004 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.464V  >> 2021-10-22 16:29:02.415 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:31:07.404 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:32:11.075 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:33:14.778 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-22 16:34:18.336 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.361V  >> 2021-10-22 16:35:21.878 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.083V  >> 2021-10-26 10:02:07.563 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.039V  >> 2021-10-26 10:03:11.095 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.039V  >> 2021-10-26 10:04:14.787 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.068V  >> 2021-10-26 10:05:18.649 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.083V  >> 2021-10-26 10:06:22.359 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.098V  >> 2021-10-26 10:07:25.894 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.098V  >> 2021-10-26 10:08:29.501 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.083V  >> 2021-10-26 10:09:33.283 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.142V  >> 2021-10-26 10:10:36.955 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.273V  >> 2021-10-26 12:07:12.575 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.317V  >> 2021-10-26 12:08:12.655 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.288V  >> 2021-10-26 12:13:41.568 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.317V  >> 2021-10-26 12:14:41.612 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.259V  >> 2021-10-26 12:16:06.110 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.493V  >> 2021-10-29 14:26:05.578 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.449V  >> 2021-10-29 14:27:07.911 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.405V  >> 2021-10-29 14:28:10.248 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.435V  >> 2021-10-29 14:29:12.409 Check Amplifier >>  13060185
#
# Invalid Voltage! >>  18.391V  >> 2021-10-29 14:30:14.739 Check Amplifier >>  13060185
